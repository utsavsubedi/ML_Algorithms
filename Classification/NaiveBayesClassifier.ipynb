# %% [markdown]
# ##Naive Bayes Classifier

# %% [markdown]
# ###Importing Necessary Libraries

# %%
import numpy as np 
import pandas as pd 
from matplotlib import pyplot as plt 
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix

# %% [markdown]
# ##Loading Dataset

# %%
df = pd.read_csv('/content/drive/My Drive/DataSets/credit_data.csv')
df
# Out:
#       clientid        income        age         loan       LTI  default
# 0            1  66155.925095  59.017015  8106.532131  0.122537        0
# 1            2  34415.153966  48.117153  6564.745018  0.190752        0
# 2            3  57317.170063  63.108049  8020.953296  0.139940        0
# 3            4  42709.534201  45.751972  6103.642260  0.142911        0
# 4            5  66952.688845  18.584336  8770.099235  0.130989        1
# ...        ...           ...        ...          ...       ...      ...
# 1995      1996  59221.044874  48.518179  1926.729397  0.032535        0
# 1996      1997  69516.127573  23.162104  3503.176156  0.050394        0
# 1997      1998  44311.449262  28.017167  5522.786693  0.124636        1
# 1998      1999  43756.056605  63.971796  1622.722598  0.037086        0
# 1999      2000  69436.579552  56.152617  7378.833599  0.106267        0
#
# [2000 rows x 6 columns]

# %% [markdown]
# ##Feature Extraction

# %%
data = df[['age', 'loan', 'income', 'default']].values
features = df[['age', 'loan', 'income']].values
label = df[['default']]

# %%
features
# Out:
# array([[5.90170151e+01, 8.10653213e+03, 6.61559251e+04],
#        [4.81171531e+01, 6.56474502e+03, 3.44151540e+04],
#        [6.31080495e+01, 8.02095330e+03, 5.73171701e+04],
#        ...,
#        [2.80171669e+01, 5.52278669e+03, 4.43114493e+04],
#        [6.39717958e+01, 1.62272260e+03, 4.37560566e+04],
#        [5.61526170e+01, 7.37883360e+03, 6.94365796e+04]])

# %%
label
# Out:
#       default
# 0           0
# 1           0
# 2           0
# 3           0
# 4           1
# ...       ...
# 1995        0
# 1996        0
# 1997        1
# 1998        0
# 1999        0
#
# [2000 rows x 1 columns]

# %% [markdown]
# ##Train_Test_Split

# %%
features_train, features_test, label_train, label_test = train_test_split( features, label, test_size = 0.2 )

# %% [markdown]
# ##Model Building , Fitting and Prediction

# %%
model = GaussianNB()
model.fit(features_train, label_train)
prediction = model.predict(features_test)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/naive_bayes.py:206: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %% [markdown]
# ##Model Evaluation

# %%
print('The confusion matrix of the model is : ')
print( confusion_matrix( label_test, prediction ) )
print('The accuracy Score is : ', accuracy_score( label_test, prediction ))
# Out:
# The confusion matrix of the model is :
# [[336   9]
#  [ 21  34]]
# The accuracy Score is :  0.925

# %%
import seaborn as sns
sns.heatmap( confusion_matrix(label_test, prediction), annot = True, cmap = 'Blues' )
